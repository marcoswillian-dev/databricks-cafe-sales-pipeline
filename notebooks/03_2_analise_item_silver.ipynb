# %%
#Lendo arquivo da bronze para analise.
df = spark.table("`cafe_sales_2026`.silver.clean_cafe_sales")
display(df)

# %%
#revisando os item distintos que temos na tebela ITEM.
from pyspark.sql.functions import countDistinct

df.select("Item").distinct().display()
print("Quantidade de itens distintos:",
      df.select(countDistinct("Item")).first()[0])

# %%
#validando preco por unidade, tomando decisão de não alterar os ERROS por existirem valores iguais. 
df_reference \
    .orderBy("Price_Per_Unit", "Item") \
    .display()
